# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values of the images to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images to be 4D tensors
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to categorical variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.2)

# Get the accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 4s 6ms/step - loss: 0.3462 - accuracy: 0.8946 - val_loss: 0.0772 - val_accuracy: 0.9780
# Epoch 2/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1075 - accuracy: 0.9685 - val_loss: 0.0634 - val_accuracy: 0.9826
# Epoch 3/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0795 - accuracy: 0.9771 - val_loss: 0.0491 - val_accuracy: 0.9862
# Epoch 4/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0659 - accuracy: 0.9804 - val_loss: 0.0446 - val_accuracy: 0.9876
# Epoch 5/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0542 - accuracy: 0.9834 - val_loss: 0.0417 - val_accuracy: 0.9878
# Epoch 6/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0459 - accuracy: 0.9859 - val_loss: 0.0374 - val_accuracy: 0.9898
# Epoch 7/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0425 - accuracy: 0.9868 - val_loss: 0.0410 - val_accuracy: 0.9898
# Epoch 8/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0363 - accuracy: 0.9883 - val_loss: 0.0347 - val_accuracy: 0.9904
# Epoch 9/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0317 - accuracy: 0.9902 - val_loss: 0.0361 - val_accuracy: 0.9902
# Epoch 10/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0287 - accuracy: 0.9908 - val_loss: 0.0373 - val_accuracy: 0.9893
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0250 - accuracy: 0.9926
# Test accuracy: 0.9926000237464905

# %% [markdown]
# Increase the number of epochs from 10 to 20

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values of the images to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images to be 4D tensors
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to categorical variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=128, epochs=20, validation_split=0.2)

# Get the accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/20
# 375/375 [==============================] - 4s 6ms/step - loss: 0.3240 - accuracy: 0.9017 - val_loss: 0.0762 - val_accuracy: 0.9778
# Epoch 2/20
# 375/375 [==============================] - 3s 7ms/step - loss: 0.1061 - accuracy: 0.9685 - val_loss: 0.0550 - val_accuracy: 0.9826
# Epoch 3/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0782 - accuracy: 0.9769 - val_loss: 0.0457 - val_accuracy: 0.9861
# Epoch 4/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0618 - accuracy: 0.9816 - val_loss: 0.0398 - val_accuracy: 0.9880
# Epoch 5/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0509 - accuracy: 0.9847 - val_loss: 0.0397 - val_accuracy: 0.9890
# Epoch 6/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0464 - accuracy: 0.9859 - val_loss: 0.0385 - val_accuracy: 0.9887
# Epoch 7/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0397 - accuracy: 0.9881 - val_loss: 0.0361 - val_accuracy: 0.9896
# Epoch 8/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0366 - accuracy: 0.9888 - val_loss: 0.0335 - val_accuracy: 0.9908
# Epoch 9/20
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0335 - accuracy: 0.9893 - val_loss: 0.0331 - val_accuracy: 0.9908
# Epoch 10/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0282 - accuracy: 0.9911 - val_loss: 0.0345 - val_accuracy: 0.9913
# Epoch 11/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0382 - val_accuracy: 0.9906
# Epoch 12/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0240 - accuracy: 0.9925 - val_loss: 0.0360 - val_accuracy: 0.9908
# Epoch 13/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0217 - accuracy: 0.9931 - val_loss: 0.0359 - val_accuracy: 0.9916
# Epoch 14/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.0393 - val_accuracy: 0.9912
# Epoch 15/20
# 375/375 [==============================] - 3s 9ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.0360 - val_accuracy: 0.9912
# Epoch 16/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0168 - accuracy: 0.9939 - val_loss: 0.0399 - val_accuracy: 0.9902
# Epoch 17/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0171 - accuracy: 0.9947 - val_loss: 0.0402 - val_accuracy: 0.9916
# Epoch 18/20
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.0384 - val_accuracy: 0.9906
# Epoch 19/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.0375 - val_accuracy: 0.9914
# Epoch 20/20
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0383 - val_accuracy: 0.9919
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0289 - accuracy: 0.9929
# Test accuracy: 0.992900013923645

# %% [markdown]
# Add another Conv2D layer with more filters

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values of the images to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images to be 4D tensors
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to categorical variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))


# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.2)

# Get the accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 5s 7ms/step - loss: 0.4627 - accuracy: 0.8540 - val_loss: 0.1151 - val_accuracy: 0.9652
# Epoch 2/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1406 - accuracy: 0.9596 - val_loss: 0.0828 - val_accuracy: 0.9729
# Epoch 3/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0987 - accuracy: 0.9710 - val_loss: 0.0756 - val_accuracy: 0.9774
# Epoch 4/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0774 - accuracy: 0.9777 - val_loss: 0.0566 - val_accuracy: 0.9839
# Epoch 5/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0641 - accuracy: 0.9812 - val_loss: 0.0655 - val_accuracy: 0.9811
# Epoch 6/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0535 - accuracy: 0.9837 - val_loss: 0.0602 - val_accuracy: 0.9818
# Epoch 7/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0466 - accuracy: 0.9859 - val_loss: 0.0507 - val_accuracy: 0.9856
# Epoch 8/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0410 - accuracy: 0.9876 - val_loss: 0.0452 - val_accuracy: 0.9861
# Epoch 9/10
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0350 - accuracy: 0.9900 - val_loss: 0.0590 - val_accuracy: 0.9827
# Epoch 10/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0319 - accuracy: 0.9905 - val_loss: 0.0555 - val_accuracy: 0.9843
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0551 - accuracy: 0.9841
# Test accuracy: 0.9840999841690063

# %% [markdown]
# Use the RMSprop optimizer instead of Adam

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values of the images to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images to be 4D tensors
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to categorical variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="rmsprop", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.2)

# Get the accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/10
# 375/375 [==============================] - 4s 7ms/step - loss: 0.3589 - accuracy: 0.8899 - val_loss: 0.0827 - val_accuracy: 0.9755
# Epoch 2/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1037 - accuracy: 0.9685 - val_loss: 0.0567 - val_accuracy: 0.9827
# Epoch 3/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0736 - accuracy: 0.9776 - val_loss: 0.0491 - val_accuracy: 0.9858
# Epoch 4/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0594 - accuracy: 0.9822 - val_loss: 0.0373 - val_accuracy: 0.9893
# Epoch 5/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0471 - accuracy: 0.9858 - val_loss: 0.0402 - val_accuracy: 0.9885
# Epoch 6/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0412 - accuracy: 0.9875 - val_loss: 0.0439 - val_accuracy: 0.9885
# Epoch 7/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0364 - accuracy: 0.9889 - val_loss: 0.0383 - val_accuracy: 0.9897
# Epoch 8/10
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0335 - accuracy: 0.9894 - val_loss: 0.0342 - val_accuracy: 0.9907
# Epoch 9/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0289 - accuracy: 0.9912 - val_loss: 0.0357 - val_accuracy: 0.9904
# Epoch 10/10
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0258 - accuracy: 0.9918 - val_loss: 0.0330 - val_accuracy: 0.9920
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0266 - accuracy: 0.9919
# Test accuracy: 0.9919000267982483

# %% [markdown]
# Increase the batch size from 128 to 256

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the pixel values of the images to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# Reshape the images to be 4D tensors
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert the labels to categorical variables
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# Create the model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation="relu", input_shape=(28, 28, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation="softmax"))

# Compile the model
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
history = model.fit(x_train, y_train, batch_size=256, epochs=10, validation_split=0.2)

# Get the accuracy and loss values
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# Plot accuracy
plt.plot(accuracy, label='Training Accuracy')
plt.plot(val_accuracy, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss')
plt.legend()
plt.show()

# Evaluate the model on the test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/10
# 188/188 [==============================] - 4s 9ms/step - loss: 0.4696 - accuracy: 0.8575 - val_loss: 0.0993 - val_accuracy: 0.9701
# Epoch 2/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.1331 - accuracy: 0.9606 - val_loss: 0.0688 - val_accuracy: 0.9798
# Epoch 3/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0934 - accuracy: 0.9722 - val_loss: 0.0526 - val_accuracy: 0.9850
# Epoch 4/10
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0758 - accuracy: 0.9770 - val_loss: 0.0473 - val_accuracy: 0.9869
# Epoch 5/10
# 188/188 [==============================] - 2s 9ms/step - loss: 0.0633 - accuracy: 0.9811 - val_loss: 0.0415 - val_accuracy: 0.9875
# Epoch 6/10
# 188/188 [==============================] - 1s 8ms/step - loss: 0.0565 - accuracy: 0.9826 - val_loss: 0.0410 - val_accuracy: 0.9885
# Epoch 7/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0473 - accuracy: 0.9852 - val_loss: 0.0379 - val_accuracy: 0.9892
# Epoch 8/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0441 - accuracy: 0.9858 - val_loss: 0.0365 - val_accuracy: 0.9891
# Epoch 9/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0386 - accuracy: 0.9884 - val_loss: 0.0364 - val_accuracy: 0.9902
# Epoch 10/10
# 188/188 [==============================] - 1s 7ms/step - loss: 0.0363 - accuracy: 0.9889 - val_loss: 0.0328 - val_accuracy: 0.9902
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0260 - accuracy: 0.9910
# Test accuracy: 0.9909999966621399
